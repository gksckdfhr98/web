# %%
# !move "C:\Users\gksck\Downloads\도로교통공단_사고유형별 교통사고 통계_20201210.csv" .
# Out:
#         1개 파일을 이동했습니다.

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 86FF-A5D5
#
#  C:\Users\gksck\git\WEB\Big-Data\Data science\file-path 디렉터리
#
# 2020-12-12  오전 10:33    <DIR>          .
# 2020-12-12  오전 10:33    <DIR>          ..
# 2020-12-12  오전 10:08    <DIR>          .ipynb_checkpoints
# 2020-12-12  오전 10:32             1,648 file-path-setting.ipynb
# 2020-12-12  오전 10:14               760 도로교통공단_사고유형별 교통사고 통계_20201210.csv
#                2개 파일               2,408 바이트
#                3개 디렉터리  25,179,013,120 바이트 남음

# %%
import pandas as pd

# %%
pd.read_csv("Data/도로교통공단_사고유형별 교통사고 통계_20201210.csv",encoding="cp949")
# Out:
#    사고유형_대분류    사고유형_중분류   사고건수  사망자수   중상자수   경상자수  부상신고자수
# 0      차대사람         횡단중  18165   922  10334   7480     638
# 1      차대사람       차도통행중   3335   162   1580   1591     168
# 2      차대사람  길가장자리구역통행중   3119    89   1140   1834     217
# 3      차대사람       보도통행중   2216    58   1080   1136     111
# 4      차대사람          기타  22295   697   9997  11605    1324
# 5       차대차        정면충돌   6330   280   4718   6911     489
# 6       차대차        측면충돌  60806   592  25850  68939    5058
# 7       차대차          추돌  43205   536  16492  62434    4097
# 8       차대차          기타  44915   525  18175  47646    3986
# 9      차량단독       공작물충돌   4500   577   2653   2562     743
# 10     차량단독        도로이탈    788   193    541    412      85
# 11     차량단독   주/정차차량 충돌     27     2     11     15       2
# 12     차량단독        전도전복   1534   267    946    787     257
# 13     차량단독          기타   4115   189   1842   2434     388
# 14    철길건널목       차단기돌파      1     0      1      0       0
# ...

# %%
# !move "C:\Users\gksck\Downloads\소상공인시장진흥공단_상가(상권)정보_20200930\소상공인시장진흥공단_상가(상권)정보_서울_202009.csv" ./Data
# Out:
#         1개 파일을 이동했습니다.
